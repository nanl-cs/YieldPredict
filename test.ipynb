# %%
print("=== Test Notebook ===")
print("Kernel running, outputs will be preserved.")
import sys, numpy as np, pandas as pd
print(f"Python: {sys.version[:20]}")
print(f"numpy: {np.__version__}")
print(f"pandas: {pd.__version__}")
# Out:
# === Test Notebook ===
# Kernel running, outputs will be preserved.
# Python: 3.10.20 (main, Mar 2
# numpy: 2.2.6
# pandas: 2.3.3

# %%
df = pd.DataFrame({"feature": ["A","B","C","D","E"], "value": [1.2,3.4,5.6,7.8,9.0], "count": [10,20,30,40,50]})
df
# Out:
#   feature  value  count
# 0       A    1.2     10
# 1       B    3.4     20
# 2       C    5.6     30
# 3       D    7.8     40
# 4       E    9.0     50

# %%
arr = np.random.RandomState(42).randn(100)
print(f"mean={arr.mean():.4f}  std={arr.std():.4f}  min={arr.min():.4f}  max={arr.max():.4f}")
# Out:
# mean=-0.1038  std=0.9036  min=-2.6197  max=1.8523

# %%
print("All cells executed!")
print("test.ipynb output preservation verified.")
# Out:
# All cells executed!
# test.ipynb output preservation verified.
